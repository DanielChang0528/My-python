# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sympy as sp

# %%
x=sp.symbols('x')
y=input("請輸入函數方程式:")
sp.plot(y)
# Out:
# 請輸入函數方程式:x**7+x**3+15
